# %%
# Preorder binary tree

class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key


# A function to do preorder tree traversal

def print_preorder(root):

    if root:
        # Print the value of the current node
        print(root.val, end=" ")
        # Recur on the left subtree
        print_preorder(root.left)
        # Recur on the right subtree
        print_preorder(root.right)

# Contoh pohon biner
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

# Cetak output "Preorder traversal of tree is 4 2 5 1 3"
print("Preorder traversal of tree binary is", end="  ")
print_preorder(root)
# Out:
# Preorder traversal of tree binary is  1 2 4 5 3
